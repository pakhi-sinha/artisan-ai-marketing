# %% [markdown]
# <a href="https://colab.research.google.com/github/pakhi-sinha/artisan-ai-marketing/blob/main/Artistproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # Upload your downloaded JSON key
# Out:
#      <input type="file" id="files-8afe7802-4a8e-41a0-aee3-08135db2d79d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8afe7802-4a8e-41a0-aee3-08135db2d79d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install google-cloud-aiplatform google-cloud-vision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.9/527.9 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import os

# Use the exact uploaded file name
service_account_file = "artisan-ai-project-56cbb2e01ab4.json"

# Set GOOGLE_APPLICATION_CREDENTIALS environment variable
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = service_account_file

# %%
# !gcloud auth activate-service-account --key-file $service_account_file
# !gcloud config set project artisan-ai-project
# Out:
# Activated service account credentials for: [artisan-service@artisan-ai-project.iam.gserviceaccount.com]
# Updated property [core/project].

# %%
# !pip install google-cloud-vision google-cloud-aiplatform

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-024cb220-8feb-4988-871c-4accfbc7dc55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-024cb220-8feb-4988-871c-4accfbc7dc55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.cloud import vision

client = vision.ImageAnnotatorClient()

# Use the uploaded image filename
file_name = "handwovenbasket.jpg"  # replace with your uploaded file name

with open(file_name, "rb") as image_file:
    content = image_file.read()

image = vision.Image(content=content)

response = client.label_detection(image=image)
labels = response.label_annotations

print("Labels detected:")
for label in labels:
    print(label.description, "-", label.score)
# Out:
# Labels detected:
# Basket - 0.9668213725090027
# Wicker - 0.8379693627357483
# Storage Basket - 0.7744559645652771
# Woven fabric - 0.7740529179573059
# Natural material - 0.7463805675506592
# Creative arts - 0.7050274014472961
# Craft - 0.7004221081733704
# Shoulder Bag - 0.6230821013450623
# Synthetic rubber - 0.5908122658729553
# Pattern - 0.5804411768913269

# %%
# Convert labels to hashtags
hashtags = []
for label in labels:
    tag = label.description.replace(" ", "").lower()
    hashtags.append(f"#{tag}")

print("Generated Hashtags for Social Media:")
print(" ".join(hashtags))
# Out:
# Generated Hashtags for Social Media:
# #basket #wicker #storagebasket #wovenfabric #naturalmaterial #creativearts #craft #shoulderbag #syntheticrubber #pattern

# %%
# Generate a simple description using top labels
top_labels = [label.description for label in labels[:3]]  # take top 3 labels
description = f"This handmade item is related to {', '.join(top_labels)}."

print("Generated Description:")
print(description)
# Out:
# Generated Description:
# This handmade item is related to Basket, Wicker, Storage Basket.

# %%
from google.cloud import translate_v2 as translate

# Initialize Translation client
translate_client = translate.Client()

# Translate into Hindi and Bengali
target_languages = ["hi", "bn"]

print("\nTranslations:")
for lang in target_languages:
    result = translate_client.translate(description, target_language=lang)
    print(f"{lang.upper()}:", result["translatedText"])
# Out:
# Translations:
# HI: यह हस्तनिर्मित वस्तु टोकरी, विकर, भंडारण टोकरी से संबंधित है।
# BN: এই হস্তনির্মিত জিনিসটি ঝুড়ি, বেতের ঝুড়ি, স্টোরেজ ঝুড়ির সাথে সম্পর্কিত।

# %%
import vertexai

PROJECT_ID = "artisan-ai-project"   # ✅ Your correct project ID
LOCATION = "us-central1"

vertexai.init(project=PROJECT_ID, location=LOCATION)
print("✅ Vertex AI initialized successfully")
# Out:
# ✅ Vertex AI initialized successfully

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import vertexai
from vertexai.generative_models import GenerativeModel

# Initialize Vertex AI
vertexai.init(project="artisan-ai-project", location="us-central1")

# Use the latest, most powerful Gemini model
model = GenerativeModel("gemini-2.5-pro")

# Your prompt and labels
labels_text = "candle, scent, lavender, calming, home decor"
prompt = f"Write a short, attractive marketing description for a handmade craft related to: {labels_text}"

# Generate the content
response = model.generate_content(prompt)

print("\n✨ AI-Generated Marketing Description:")
print(response.text)
# Out:
# ✨ AI-Generated Marketing Description:
# Of course! Here are a few options, from short and punchy to slightly more descriptive.
#
# ### Option 1 (Short & Sweet)
#
# **Unwind with handcrafted serenity.** Our hand-poured lavender candle fills your space with a calming aroma, creating a peaceful sanctuary. A beautiful piece of decor for a tranquil home.
#
# ### Option 2 (Benefit-Focused)
#
# **Find your moment of calm.** Light this artisan lavender candle and let its gentle, soothing scent melt away the day's stress. Made with pure essential oils, it’s the perfect blend of elegant home decor and pure tranquility.
#
# ### Option 3 (Decor-Focused)
#
# **Beauty meets tranquility.** Adorn your home with our stunning, handcrafted candle. Its chic design elevates any room, while the serene scent of pure lavender creates a calm and inviting atmosphere. The perfect accent for a peaceful space.

# %%
from google.colab import files

uploaded = files.upload()  # This will open a file selector
# Out:
#      <input type="file" id="files-a6e91288-6212-432f-b5b2-4e963ce2d167" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6e91288-6212-432f-b5b2-4e963ce2d167">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Use the exact filename of the uploaded JSON
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "artisan-ai-project-56cbb2e01ab4 (1).json"

# %%
from google.cloud import texttospeech, speech

tts_client = texttospeech.TextToSpeechClient()
stt_client = speech.SpeechClient()

# %%
import os

# Rename the uploaded file to a simpler name
os.rename("artisan-ai-project-56cbb2e01ab4 (1).json", "artisan-service.json")

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "artisan-service.json"

# %%
from google.cloud import texttospeech, speech

tts_client = texttospeech.TextToSpeechClient()
stt_client = speech.SpeechClient()

# %%
# ---------------------------
# Text-to-Speech for your craft
# ---------------------------
marketing_text = "This handmade craft features a wooden handmade basket. Perfect for gifts and home decoration."

synthesis_input = texttospeech.SynthesisInput(text=marketing_text)

voice = texttospeech.VoiceSelectionParams(
    language_code="en-US",
    ssml_gender=texttospeech.SsmlVoiceGender.FEMALE
)

audio_config = texttospeech.AudioConfig(audio_encoding=texttospeech.AudioEncoding.MP3)

response = tts_client.synthesize_speech(
    input=synthesis_input,
    voice=voice,
    audio_config=audio_config
)

tts_file = "handmade_basket.mp3"
with open(tts_file, "wb") as out:
    out.write(response.audio_content)

print(f"✅ TTS audio saved: {tts_file}")

# Play the audio in Colab
from IPython.display import Audio
Audio(tts_file, autoplay=True)
# Out:
# ✅ TTS audio saved: handmade_basket.mp3
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pydub

# Convert MP3 to WAV
audio = pydub.AudioSegment.from_mp3(tts_file)
wav_file = "handmade_basket.wav"
audio.export(wav_file, format="wav")

with open(wav_file, "rb") as f:
    content = f.read()

audio_input = speech.RecognitionAudio(content=content)
config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=audio.frame_rate,
    language_code="en-US"
)

stt_response = stt_client.recognize(config=config, audio=audio_input)

for result in stt_response.results:
    print("🎤 STT transcription:", result.alternatives[0].transcript)
# Out:
# 🎤 STT transcription: this handmade crafts features a wooden handmade basket perfect for gifts and home decoration
